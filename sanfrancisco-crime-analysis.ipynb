# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

import folium
import os
print(os.listdir("C:\\Users\\KIIT\\Documents\\Python Scripts\\Sanfrancisco-Crime-Dataset-master\\Police_Department_Incidents_-_Previous_Year__2016_"))
# Out:
# ['Police_Department_Incidents_-_Previous_Year__2016_.csv']

# %%
data = pd.read_csv('C:\\Users\\KIIT\\Documents\\Python Scripts\\Sanfrancisco-Crime-Dataset-master\\Police_Department_Incidents_-_Previous_Year__2016_\\Police_Department_Incidents_-_Previous_Year__2016_.csv')

data.shape
# Out:
# (150500, 13)

# %%
data.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
plt.rcParams['figure.figsize'] = (20, 9)
sns.countplot(data['Category'], palette = 'gnuplot')
plt.title('Major Crimes in Sanfrancisco', fontweight = 30, fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
gjson = r'http://fontawesome.io/icons/'
sf_map = folium.Map(location = [37.77, -122.42], zoom_start = 12)

# %%
sf_map.choropleth(
    geo_data=gjson,
    data=table,
    columns=['Neighborhood', 'Count'],
    key_on='feature.properties.DISTRICT',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Crime Rate in San Francisco'
)
sf_map
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32832/3549604256.py in <module>
#       1 #generate map
# ----> 2 sf_map.choropleth(
#       3     geo_data=gjson,
#       4     data=table,
#       5     columns=['Neighborhood', 'Count'],
#
# ~\anaconda3\lib\site-packages\folium\folium.py in choropleth(self, *args, **kwargs)
#     414         )
#     415         from folium.features import Choropleth
# --> 416         self.add_child(Choropleth(*args, **kwargs))
#     417
#     418     def keep_in_front(self, *args):
#
# ~\anaconda3\lib\site-packages\folium\features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
# ...
